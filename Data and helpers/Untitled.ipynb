# %%
import pandas as pd

df = pd.read_csv('test_clv.csv', sep=";")

# %%
df.drop(columns='Unnamed: 6').head()
# Out:
#    Unnamed: 0  Customer ID  frequency  recency    T  monetary_value
# 0           0        12346         10      400  725      -15.468000
# 1           1        12347          7      402  404      717.398571
# 2           2        12348          4      363  438      449.310000
# 3           3        12349          4      717  735     1107.172500
# 4           4        12350          0        0  310        0.000000

# %%
df_ = df.to_csv('test_clv1.csv')

# %%
df_ = pd.read_csv('test_clv1.csv')

# %%
df_
# Out:
#      Unnamed: 0  Unnamed: 0.1  Customer ID  frequency  recency    T  \
# 0             0             0        12346         10      400  725
# 1             1             1        12347          7      402  404
# 2             2             2        12348          4      363  438
# 3             3             3        12349          4      717  735
# 4             4             4        12350          0        0  310
# ..          ...           ...          ...        ...      ...  ...
# 204         204           204        12550          0        0   79
# 205         205           205        12551          0        0  357
# 206         206           206        12552          1        1   39
# 207         207           207        12553         15      415  423
# 208         208           208        12554          0        0  448
#
#      monetary_value  Unnamed: 6
# 0        -15.468000         NaN
# 1        717.398571         NaN
# 2        449.310000         NaN
# ...
